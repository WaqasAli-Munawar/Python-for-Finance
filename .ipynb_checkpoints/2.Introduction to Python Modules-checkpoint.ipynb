# %% [markdown]
# In this chapter, we will discuss the most important issues related to Python modules, which are packages written by experts or any individual to serve a special purpose.

# %% [markdown]
# Knowledge related to modules is critical in our understanding of Python and its application to finance.

# %% [markdown]
# ### What is a Python module?
#
# A module is a package or group of programs that is written by an expert, user, or even a beginner who is usually very good in a specific area, to serve a specific purpose.
#
# For example, a Python module called **quant** is for **quantitative financial analysis**. quant combines two modules of **SciPy** and **DomainModel**.
# * The module contains a domain model that has exchanges, symbols, markets, and historical prices, among other things.
#
# Modules are very important in Python. We will discuss about a dozen modules implicitly or explicitly. In particular, we will explain five modules in detail:
# * NumPy,
# * SciPy,
# * matplotlib,
# * statsmodels, and
# * Pandas.

# %% [markdown]
# As of November 16, 2016, there are **92,872 Python modules (packages)** with different areas available according to the Python Package Index. For the financial and insurance industries, there are **384 modules** currently available.

# %%
import math
x=math.sqrt(3)
round(x,4)
# Out:
# 1.7321

# %%
print(dir())
# Out:
# ['In', 'Out', '_', '_1', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i2', '_ih', '_ii', '_iii', '_oh', 'exit', 'get_ipython', 'math', 'quit', 'x']

# %%
'math' in dir()
# Out:
# True

# %% [markdown]
# We also observe `__builtins__`. There are two underscores, before and after builtin. This `__builtins__` module is different from other built-in modules, such as the math module. It is for all built-in functions and other objects. Again, the command of `dir(__builtins__)` could be issued to list all built-in functions

# %%
print(dir(__builtins__))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EnvironmentError', 'Exception', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 'StopIteration', 'SyntaxError', 'SyntaxWarning', 'SystemErr
# ...

# %%
"pow" in dir(__builtins__)
# Out:
# True

# %% [markdown]
# From the preceding output, we find a function called `pow()`. The command of `help(pow)` could be used to find more information about this specific function; see the following:

# %%
help(pow)
# Out:
# Help on built-in function pow in module builtins:
#
# pow(x, y, z=None, /)
#     Equivalent to x**y (with two arguments) or x**y % z (with three arguments)
#
#     Some types, such as ints, are able to use a more efficient algorithm when
#     invoked using the three argument form.

# %%
two_exp_3 = pow(2,3)
two_exp_3
# Out:
# 8

# %%
two_exp_3_mod_2 = pow(2,3,2)
two_exp_3_mod_2
# Out:
# 0

# %% [markdown]
# When calling a specific function contained in an imported module, we use the module's short name, as shown in the following lines of code:

# %%
import time as t
t.localtime()
# Out:
# time.struct_time(tm_year=2021, tm_mon=4, tm_mday=5, tm_hour=20, tm_min=12, tm_sec=54, tm_wday=0, tm_yday=95, tm_isdst=0)

# %% [markdown]
# To show all functions in an imported module, the `dir(module)` command could be used, as shown in the following lines of code:

# %%
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'ceil', 'copysign', 'cos', 'cosh', 'degrees', 'e', 'erf', 'erfc', 'exp', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'pi', 'pow', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc']

# %% [markdown]
# The `del()` function is used to remove an imported/uploaded module which is deemed unnecessary, as shown in the following lines of code:

# %%
print(dir())
# Out:
# ['In', 'Out', '_', '_1', '_3', '_5', '_7', '_8', '_9', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i2', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'exit', 'get_ipython', 'math', 'quit', 't', 'two_exp_3', 'two_exp_3_mod_2', 'x']

# %%
del math

print(dir())
# Out:
# ['In', 'Out', '_', '_1', '_3', '_5', '_7', '_8', '_9', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i2', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'exit', 'get_ipython', 'quit', 't', 'two_exp_3', 'two_exp_3_mod_2', 'x']

# %% [markdown]
# On the other hand, if we use `from math import *`, we cannot remove all functions, just issue `del math`. We have to remove those individual functions separately.

# %%
from math import *
del math
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-cff7867acba6> in <module>
#       1 from math import *
# ----> 2 del math
#
# NameError: name 'math' is not defined

# %% [markdown]
# For convenience, we could import only a few needed functions. To price a European call option, several functions are needed, such as `log()`, `exp()`, `sqrt()` and `cdf()`.
# * `cdf()` is the function for **cumulative standard normal distribution**.
#
# To make those four functions available, we specify their names, as shown in the following lines of code:

# %%
from scipy import log,exp,sqrt,stats

# %% [markdown]
# The complete codes for pricing Black-Scholes-Merton call options are given here:

# %%
def bsCall(S,X,T,r,sigma):
    from scipy import log,exp,sqrt,stats
    d1=(log(S/X)+(r+sigma*sigma/2.)*T)/(sigma*sqrt(T))
    d2 = d1-sigma*sqrt(T)
    return S*stats.norm.cdf(d1)-X*exp(-r*T)*stats.norm.cdf(d2)

# %%
bsCall(40,40,0.1,0.05,0.2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: scipy.log is deprecated and will be removed in SciPy 2.0.0, use numpy.lib.scimath.log instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: scipy.sqrt is deprecated and will be removed in SciPy 2.0.0, use numpy.lib.scimath.sqrt instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: scipy.sqrt is deprecated and will be removed in SciPy 2.0.0, use numpy.lib.scimath.sqrt instead
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: scipy.exp is deprecated and will be removed in SciPy 2.0.0, use numpy.exp instead
#   """
# 1.1094616585675574

# %% [markdown]
# To find all available modules, a help window should be activated first. After that, issue modules. The result is shown here:

# %%
help()
# Out:
# Welcome to Python 3.7's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.7/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# help> quit
#
# You are now leaving help and returning to the Python interpreter.
# If you want to ask for help on a particular object directly from the
# interpreter, you can type "help(object)".  Executing "help('string')"
# has the same effect as typing a particular string at the help> prompt.

# %% [markdown]
# Enter the name of any module, keyword, or topic to get help on writing Python programs and using Python modules. To quit this help utility and return to the interpreter, just type **quit**

# %% [markdown]
# To get a list of available **modules**, **keywords**, **symbols**, or **topics**, type
# * modules,
# * keywords,
# * symbols, or
# * topics.
#
# Each module also comes with a one-line summary of what it does;
# * to list the modules whose name or summary contain a given string such as spam, type `modules spam`:

# %%
# help("modules spam")

# %% [markdown]
# To find a specific module, we just type modules followed by the module's name. Assume that we are interested in the module called `cmd`. Then, we issue modules `cmd` in the help window

# %%
# help("modules cmd")

# %% [markdown]
# ### Introduction to NumPy
#
# In the following examples, the `np.size()` function from NumPy shows the number of data items of an array, and the `np.std()` function is used to calculate standard deviation:

# %%
import numpy as np

x= np.array([[1,2,3],[3,4,6]]) # 2 by 3 matrix
np.size(x) # number of data items
# Out:
# 6

# %%
np.size(x,1) # show number of columns
# Out:
# 3

# %%
np.std(x)
# Out:
# 1.5723301886761005

# %%
np.std(x,1) # axis = 1 will result row wise
# Out:
# array([0.81649658, 1.24721913])

# %%
total=x.sum() # attention to the format
z=np.random.rand(50) #50 random observatio from normal distributio [0.0, 1) 
z

# getting a value between 0-1 following methods may be used;
# 1. Divide each value by sum of all values
# 2. (x-min)/(max-min)
# Out:
# array([0.66925285, 0.96344151, 0.01648623, 0.24109398, 0.27400697,
#        0.368689  , 0.59541892, 0.31221964, 0.5038691 , 0.62887892,
#        0.72627358, 0.94991416, 0.03236277, 0.20315244, 0.36418635,
#        0.72139144, 0.0593603 , 0.80953721, 0.10823084, 0.75929735,
#        0.6498088 , 0.12994967, 0.85894216, 0.86549727, 0.70409651,
#        0.03168889, 0.1869895 , 0.09847186, 0.22647512, 0.12268174,
#        0.53443228, 0.31171873, 0.85437016, 0.98229938, 0.73745901,
#        0.58867152, 0.07946105, 0.42120394, 0.3009098 , 0.69744819,
#        0.87533053, 0.27991677, 0.27118323, 0.94131743, 0.72057845,
#        0.11067076, 0.46241382, 0.42028077, 0.83127219, 0.03495334])

# %%
y=np.random.normal(size=100) # from standard normal - Z-score = (x-mean)/std
y
# Out:
# array([ 8.01247913e-01,  2.98275718e-01, -3.95794568e-01, -4.14004478e-01,
#        -5.44910451e-01,  3.46251334e+00,  1.42883231e+00, -4.05727331e-01,
#         1.09232182e+00,  9.54996527e-02,  6.34687376e-02, -6.30522652e-01,
#         9.16112502e-01, -5.78688972e-01,  1.64085771e-01,  4.79382444e-01,
#        -5.69081386e-01, -2.16902072e-01,  1.11897557e+00,  3.38704534e-01,
#         5.63885141e-01,  2.15116908e+00,  3.78156895e-01, -1.01766854e+00,
#         5.71800439e-01,  1.47965936e+00,  1.32991458e-03, -5.83280030e-01,
#         2.87212759e-01,  1.90946158e+00, -2.22953849e-01, -8.25559944e-01,
#        -8.43235379e-01,  3.87684059e-01,  2.83694266e-01,  1.74896978e+00,
#        -1.57531301e+00, -1.53463898e+00, -5.03317817e-01,  9.23275448e-01,
#         5.16994303e-01, -5.14390453e-01,  4.00659424e-01,  7.42107593e-01,
#        -6.96888712e-01,  7.93438058e-01, -1.56565643e+00,  9.01734674e-01,
# ...

# %% [markdown]
# Compared with a Python array, a NumPy array is a contiguous piece of memory that is passed directly to **LAPACK**, which is a software library for numerical linear algebra under the hood, so that matrix manipulation is very fast in Python.
# * An array in NumPy is like a matrix in MATLAB.
# * Unlike lists in Python, an array should contain the same data type.

# %%
np.array([100,0.1,2],float) # dtype = float
# Out:
# array([100. ,   0.1,   2. ])

# %%
x=[1,2,3,20]
y=np.array(x,dtype=float)
y
# Out:
# array([ 1.,  2.,  3., 20.])

# %% [markdown]
# To show all functions contained in Numpy

# %%
import numpy as np

# %%
dir(np)
# Out:
# ['_InterceptedNumpy__current_numpy',
#  '_InterceptedNumpy__prev_numpy',
#  '__own_attrs__']

# %%
# dir(np._InterceptedNumpy__current_numpy)

# %% [markdown]
# Actually, a better way is to generate an array containing all functions as follows:

# %%
x=np.array(dir(np._InterceptedNumpy__current_numpy))
len(x)
# Out:
# 623

# %%
x[202:250]
# Out:
# array(['disp', 'distutils', 'divide', 'divmod', 'doc', 'dot', 'double',
#        'dsplit', 'dstack', 'dtype', 'dual', 'e', 'ediff1d', 'einsum',
#        'einsum_path', 'emath', 'empty', 'empty_like', 'equal', 'errstate',
#        'euler_gamma', 'exp', 'exp2', 'expand_dims', 'expm1', 'extract',
#        'eye', 'f2py', 'fabs', 'fastCopyAndTranspose', 'fft',
#        'fill_diagonal', 'find_common_type', 'finfo', 'fix', 'flatiter',
#        'flatnonzero', 'flexible', 'flip', 'fliplr', 'flipud', 'float',
#        'float16', 'float32', 'float64', 'float_', 'float_power',
#        'floating'], dtype='<U25')

# %% [markdown]
# It is easy to find out more information about a specific function. After issuing `dir(np)`, the `std()` function appears, among others. To seek more information about this function, `help(np.std)` is used. The following shows only a few lines of code for brevity:

# %%
help(np.std)
# Out:
# Help on function std in module numpy:
#
# std(a, axis=None, dtype=None, out=None, ddof=0, keepdims=<no value>)
#     Compute the standard deviation along the specified axis.
#
#     Returns the standard deviation, a measure of the spread of a distribution,
#     of the array elements. The standard deviation is computed for the
#     flattened array by default, otherwise over the specified axis.
#
#     Parameters
#     ----------
#     a : array_like
#         Calculate the standard deviation of these values.
#     axis : None or int or tuple of ints, optional
#         Axis or axes along which the standard deviation is computed. The
#         default is to compute the standard deviation of the flattened array.
#
#         .. versionadded:: 1.7.0
#
#         If this is a tuple of ints, a standard deviation is performed over
#         multiple axes, instead of a single axis or all the axes as before.
#     dtype : dtype, optional
# ...

# %% [markdown]
# ### Introduction to SciPy
#
# The following are a few examples based on the functions enclosed in the SciPy
# module. The `sp.npv()` function estimates the present values for a given set of cash
# flows with the first cash flow happening at time zero.
# 1. The first input value is the discount rate, and
# 2. the second input is an array of all cash flows.

# %%
import scipy as sp
cashflows=[-100,50,40,20,10,50]
x=sp.npv(0.1,cashflows)
round(x,2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: scipy.npv is deprecated and will be removed in SciPy 2.0.0, use numpy.npv instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# 31.41

# %% [markdown]
# The `sp.pmt()` function is used to answer the following question.
# * What is the monthly cash flow to pay off a mortgage of `$250,000` over `30 years` with an **annual percentage rate (APR)** of `4.5 percent`, **compounded monthly?** The following code shows the answer:

# %%
payment=sp.pmt(0.045/12,30*12,250000)
round(payment,2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: scipy.pmt is deprecated and will be removed in SciPy 2.0.0, use numpy.pmt instead
#   """Entry point for launching an IPython kernel.
# -1266.71

# %% [markdown]
# Based on the preceding result, the monthly payment will be `$1,266.71`. It might be
# quite strange that we have a negative value. Actually, this `sp.pmt()` function mimics
# the equivalent function in Excel, as we will see in the following screenshot:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The input values are:
# * the effective period rate,
# * the number of the period, and
# * the present value.

# %% [markdown]
# Similarly, the `sp.pv()` function replicates the **Excel PV() function**. For the `sp.pv()`
# function, its input format is `sp.pv(rate, nper, pmt, fv=0.0, when='end')`,
# where
# * `rate` is the **discount rate**,
# * `nper` is the **number of periods**,
# * `pmt` is the **period payment**, and
# * `fv` is the **future value** with a **default value of zero**.
# * The last input variable specifies whether the cash flows are at the end of each time period or at the beginning of each period. By default, it is at the end of each period.
#
# The following commands show how to call this function:

# %%
pv1=sp.pv(0.1,5,0,100) # pv of one future cash flow
round(pv1,2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: scipy.pv is deprecated and will be removed in SciPy 2.0.0, use numpy.pv instead
#   """Entry point for launching an IPython kernel.
# -62.09

# %%
pv2=sp.pv(0.1,5,100) # pv of annuity
round(pv2,2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: scipy.pv is deprecated and will be removed in SciPy 2.0.0, use numpy.pv instead
#   """Entry point for launching an IPython kernel.
# -379.08

# %% [markdown]
# The `sp.fv()` function has a setting similar to that of `sp.pv()`.
#
# In finance, we estimate both **arithmetic and geometric means**, which are defined in the following formulas.
#
# ![image.png](attachment:image.png)

# %%
(2+3+4)/3.
# Out:
# 3.0

# %%
geo_mean=(2*3*4)**(1./3)
round(geo_mean,4)
# Out:
# 2.8845

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# To estimate a geometric mean, the `sp.prod()` function would be applied. The
# function gives us the products of all data items;

# %%
ret=sp.array([0.1,0.05,-0.02])
sp.mean(ret) # arithmetic mean
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: scipy.array is deprecated and will be removed in SciPy 2.0.0, use numpy.array instead
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: scipy.mean is deprecated and will be removed in SciPy 2.0.0, use numpy.mean instead
# 0.04333333333333334

# %%
pow(sp.prod(ret+1),1./len(ret))-1 # geometric mean
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: scipy.prod is deprecated and will be removed in SciPy 2.0.0, use numpy.prod instead
#   """Entry point for launching an IPython kernel.
# 0.04216388706767926

# %% [markdown]
# Actually, a simple Python function could be written with just two lines to calculate a
# geometric mean for a set of given returns; see the following code:

# %%
def geoMeanReturn(ret):
    return pow(sp.prod(ret+1),1./len(ret))-1

# %%
ret=sp.array([0.1,0.05,-0.02])
geoMeanReturn(ret)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: scipy.array is deprecated and will be removed in SciPy 2.0.0, use numpy.array instead
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: scipy.prod is deprecated and will be removed in SciPy 2.0.0, use numpy.prod instead
# 0.04216388706767926

# %% [markdown]
# Two other useful functions are `sp.unique()` and `sp.median()`

# %%
sp.unique([2,3,4,6,6,4,4])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: scipy.unique is deprecated and will be removed in SciPy 2.0.0, use numpy.unique instead
#   """Entry point for launching an IPython kernel.
# array([2, 3, 4, 6])

# %%
sp.median([1,2,3,4,5])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: scipy.median is deprecated and will be removed in SciPy 2.0.0, use numpy.median instead
#   """Entry point for launching an IPython kernel.
# 3.0

# %% [markdown]
# **Python's** `sp.pv()`, `sp.fv()`, and `sp.pmt()` functions behave like **Excel's** `pv()`, `fv()`,
# and `pmt()` functions, respectively. They have the same sign convention: the sign of
# the present value is the opposite of the future value.

# %% [markdown]
# In the following example, to estimate a present value if we enter a positive future
# value, we will end up with a negative present value:

# %%
round(sp.pv(0.1,5,0,100),2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: scipy.pv is deprecated and will be removed in SciPy 2.0.0, use numpy.pv instead
#   """Entry point for launching an IPython kernel.
# -62.09

# %%
round(sp.pv(0.1,5,0,-100),2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: scipy.pv is deprecated and will be removed in SciPy 2.0.0, use numpy.pv instead
#   """Entry point for launching an IPython kernel.
# 62.09

# %% [markdown]
# There are several ways to find out all the functions contained in the SciPy module.
# Firstly, we can read related manuals. Secondly, we can issue the following lines
# of code:

# %%
import scipy as sp

x = dir(sp)
len(x)
# Out:
# 603

# %% [markdown]
# ### Introduction to matplotlib
#
# Graphs and other visual representations have become more important in explaining
# many complex financial concepts, trading strategies, and formulas.
#
# The matplotlib module is designed to produce
# publication-quality figures and graphs. The matplotlib module depends on **NumPy**
# and **SciPy**. To save generated graphs,
# there are several output formats available, such as **PDF**, **Postscript**, **SVG**, and **PNG**.
#
# By default, the
# matplotlib module assumes that the x axis starts at zero and moves by one on every
# element of the array

# %%
from matplotlib.pyplot import *

plot([1,2,3,9])
xlabel("x-axis")
ylabel("my numbers")
title("my graph")
show()

# %%
from pylab import *

# %%
x = np.linspace(start = -np.pi, stop = np.pi,num = 256,endpoint = True) # If endpoint True, `stop` is the last sample. Otherwise, it is not included.
c,s = np.cos(x), np.sin(x)
plot(x,c), plot(x,s)
show()

# %% [markdown]
# The following example shows the scatter
# pattern. First, the `np.random.normal()` function is used to generate two sets of
# random numbers. Since `n` is `1024`, we have `1,024` observations for both X and Y
# variables.

# %%
from pylab import scatter

n = 1024

x = np.random.normal(0,1,n)
y = np.random.normal(0,1,n)

scatter(x,y)
show()

# %% [markdown]
# Here is a more complex graph showing the stock movement. Let's look at the
# code first:

# %%
# ! pip install https://github.com/matplotlib/mpl_finance/archive/master.zip

# %%
# import datetime
# import matplotlib.pyplot as plt
# from matplotlib.finance import quotes_historical_yahoo_ochl
# from matplotlib.dates import MonthLocator,DateFormatter

# %%
# ticker='AAPL'
# begdate= datetime.date( 2012, 1, 2 )
# enddate = datetime.date( 2013, 12,5)
# months = MonthLocator(range(1,13), bymonthday=1, interval=3) # every 3rd month
# monthsFmt = DateFormatter("%b '%Y")

# %%
# x = quotes_historical_yahoo_ochl(ticker, begdate, enddate)

# if len(x) == 0:
#     print ('Found no quotes')
#     raise SystemExit
    
# dates = [q[0] for q in x]
# closes = [q[4] for q in x]

# %%
# fig, ax = plt.subplots()
# ax.plot_date(dates, closes, '-')
# ax.xaxis.set_major_locator(months)
# ax.xaxis.set_major_formatter(monthsFmt)
# ax.xaxis.set_minor_locator(mondays)
# ax.autoscale_view()
# ax.grid(True)
# fig.autofmt_xdate()

# %% [markdown]
# The corresponding graph is shown here:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Statsmodels
#
# **statsmodels** is a powerful Python package for many types of statistical analysis. In statistics, **ordinary least square (OLS) regression** is a method for
# estimating the unknown parameters in a **linear regression model**. It minimizes the sum
# of squared vertical distances between the observed values and the values predicted
# by the linear approximation.
#
# The OLS method is used extensively in finance. Assume
# that we have the following equation, where **y** is an **n by 1 vector (array)**, and **x** is an **n
# by (m+1) matrix**, a **return matrix (n by m), plus a vector that contains 1 only**.
# * **n** is the number of observations, and
# * **m** is the number of independent variables:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# In the following program, after generating the **x and y vectors**, we run an **OLS
# regression (a linear regression)**. The **x and y are artificial data**. The last line prints the
# parameters only (the intercept is 1.28571420 and the slope is 0.35714286):

# %%
import numpy as np
import statsmodels.api as sm

y=[1,2,3,4,2,3,4]
x=range(1,8)

x=sm.add_constant(x)
results=sm.OLS(y,x).fit()
results.params
# Out:
# array([1.28571429, 0.35714286])

# %% [markdown]
# To find out more information about this module, the `dir()` function could be used:

# %%
 import statsmodels as sm
print(dir(sm))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__init__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_version', 'api', 'base', 'compat', 'datasets', 'debug_warnings', 'discrete', 'distributions', 'duration', 'emplike', 'formula', 'gam', 'genmod', 'graphics', 'imputation', 'iolib', 'multivariate', 'nonparametric', 'regression', 'robust', 'sandbox', 'stats', 'test', 'tools', 'tsa']

# %%
# For various submodules

import statsmodels.api as api
print(dir(api))
# Out:
# ['BayesGaussMI', 'BinomialBayesMixedGLM', 'Factor', 'GEE', 'GLM', 'GLMGam', 'GLS', 'GLSAR', 'GeneralizedPoisson', 'Logit', 'MANOVA', 'MI', 'MICE', 'MICEData', 'MNLogit', 'MixedLM', 'NegativeBinomial', 'NegativeBinomialP', 'NominalGEE', 'OLS', 'OrdinalGEE', 'PCA', 'PHReg', 'Poisson', 'PoissonBayesMixedGLM', 'ProbPlot', 'Probit', 'QuantReg', 'RLM', 'RecursiveLS', 'SurvfuncRight', 'WLS', 'ZeroInflatedGeneralizedPoisson', 'ZeroInflatedNegativeBinomialP', 'ZeroInflatedPoisson', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '__version__', 'add_constant', 'categorical', 'cov_struct', 'datasets', 'distributions', 'duration', 'emplike', 'families', 'formula', 'gam', 'genmod', 'graphics', 'iolib', 'load', 'load_pickle', 'multivariate', 'nonparametric', 'os', 'qqline', 'qqplot', 'qqplot_2samples', 'regression', 'robust', 'show_versions', 'stats', 'test', 'tools', 'tsa', 'webdoc']

# %% [markdown]
# ### Pandas

# %% [markdown]
# The **pandas module** is a powerful tool used to process various types of data, including
# * Economics,
# * Financial, and
# * Accounting data.
#
# In the following example, we generate two time series starting from January 1, 2013.
# The names of those two time series (columns) are A and B:

# %%
import numpy as np
import pandas as pd

dates=pd.date_range('20160101',periods=5)
np.random.seed(12345)
x=pd.DataFrame(np.random.rand(5,2),index=dates,columns=('A','B'))
x
# Out:
#                    A         B
# 2016-01-01  0.929616  0.316376
# 2016-01-02  0.183919  0.204560
# 2016-01-03  0.567725  0.595545
# 2016-01-04  0.964515  0.653177
# 2016-01-05  0.748907  0.653570

# %%
 x.describe()
# Out:
#               A         B
# count  5.000000  5.000000
# mean   0.678936  0.484646
# std    0.318866  0.209761
# min    0.183919  0.204560
# 25%    0.567725  0.316376
# 50%    0.748907  0.595545
# 75%    0.929616  0.653177
# max    0.964515  0.653570

# %%
print(dir(pd))
# Out:
# ['BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Float64Index', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int64Index', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt64Index', 'UInt8Dtype', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__getattr__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_config', '_hashtable', '_is_numpy_dev', '_lib', '_libs', '_np_version_under1p16', '_np_version_under1p17', '_np_version_under1p18', '_testing', '_tslib', '_typing', '_version', 'api', 'array', 'arrays', 'bdate_range', 'co
# ...

# %% [markdown]
# From the preceding output, it can be seen that 16 functions start with the word read;
# see the following table:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Assume that we plan to replace missing values (NaN) with the mean of the time series. The two functions used are `mean()` and `fillna()`:

# %%
x=pd.Series([1,4,-3,np.nan,5])

m=np.mean(x)
x.fillna(m)
# Out:
# 0    1.00
# 1    4.00
# 2   -3.00
# 3    1.75
# 4    5.00
# dtype: float64

# %% [markdown]
# In the following code, we generate a DataFrame by using the
# `dataFrame()` function contained in the pandas module:

# %%
np.random.seed(123)
df = pd.DataFrame(np.random.randn(10, 4)) # Standard distribution (Z-score)
df
# Out:
#           0         1         2         3
# 0 -1.085631  0.997345  0.282978 -1.506295
# 1 -0.578600  1.651437 -2.426679 -0.428913
# 2  1.265936 -0.866740 -0.678886 -0.094709
# 3  1.491390 -0.638902 -0.443982 -0.434351
# 4  2.205930  2.186786  1.004054  0.386186
# 5  0.737369  1.490732 -0.935834  1.175829
# 6 -1.253881 -0.637752  0.907105 -1.428681
# 7 -0.140069 -0.861755 -0.255619 -2.798589
# 8 -1.771533 -0.699877  0.927462 -0.173636
# 9  0.002846  0.688223 -0.879536  0.283627

# %% [markdown]
# In the following code,
# how to use different ways to interpolate is presented:

# %%
np.random.seed(123) # fix the random numbers
x=np.arange(1, 10.1, .25)**2
n=np.size(x)
y = pd.Series(x + np.random.randn(n))

# %%
bad=np.array([4,13,14,15,16,20,30]) # generate a few missing values
y[bad] = np.nan # missing code is np.nan
methods = ['linear', 'quadratic', 'cubic']

# %%
df = pd.DataFrame({m: y.interpolate(method=m) for m in methods})
df.head(10)
# Out:
#       linear  quadratic      cubic
# 0  -0.085631  -0.085631  -0.085631
# 1   2.559845   2.559845   2.559845
# 2   2.532978   2.532978   2.532978
# 3   1.556205   1.556205   1.556205
# 4   4.135071   4.664368   4.794723
# 5   6.713937   6.713937   6.713937
# 6   3.823321   3.823321   3.823321
# 7   7.133587   7.133587   7.133587
# 8  10.265936  10.265936  10.265936
# 9   9.695760   9.695760   9.695760

# %%
import matplotlib.pyplot as plt
df.plot()
plt.show()

# %% [markdown]
# Usually, different languages have their own types of datasets.
# For example, **SAS** has its datasets with an extension of `.sas7bdat`.
# For **R**, its extensions could be `.RData`, `.rda`, or `.rds`. This is true for Python to have
# its own datasets. One type of dataset is with an extension of `.pickle` or `.pkl`. Let's
# generate a **pickle dataset**;

# %%
np.random.seed(123)
df=pd.Series(np.random.randn(100))
df.to_pickle('test.pkl')

# %%
# To read a pickle dataset

x=pd.read_pickle("test.pkl")

# %% [markdown]
# Merging two different sets is one of the common procedures researchers are
# routinely doing. The objective of the following program is to merge two datasets
# based on their common variable called **key**:

# %%
x = pd.DataFrame({'key':['A','B','C','D'],'value': [0.1,0.2,-0.5,0.9]})
y = pd.DataFrame({'key':['B','D','D','E'],'value': [2, 3, 4, 6]})
z=pd.merge(x, y, on='key')
z # inner join
# Out:
#   key  value_x  value_y
# 0   B      0.2        2
# 1   D      0.9        3
# 2   D      0.9        4

# %% [markdown]
# For finance, time series occupy a unique position since many datasets are in the form
# of time series, such as stock prices and returns. Thus, knowing how to define a date
# variable and study related functions is essential for processing economics, financial,
# and accounting data. Let's look at a few examples:

# %%
date1=pd.datetime(2010,2,3)
date1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   """Entry point for launching an IPython kernel.
# datetime.datetime(2010, 2, 3, 0, 0)

# %% [markdown]
# The difference between two dates can be easily estimated;

# %%
date2=pd.datetime(2010,3,31)
date2-date1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   """Entry point for launching an IPython kernel.
# datetime.timedelta(days=56)

# %%
date1.weekday()
# Out:
# 2

# %% [markdown]
# Under certain situations, users might want to stack data together or the other way
# around; see the following code:

# %%
np.random.seed(1256)
df=pd.DataFrame(np.random.randn(4,2),columns=['Stock A','Stock B'])
df2=df.stack()
df2
# Out:
# 0  Stock A    0.452820
#    Stock B   -0.892822
# 1  Stock A   -0.476880
#    Stock B    0.393239
# 2  Stock A    0.961438
#    Stock B   -1.797336
# 3  Stock A   -1.168289
#    Stock B    0.187016
# dtype: float64

# %% [markdown]
# The opposite operation of stock is to apply the `unstack()` function; see the
# following code:

# %%
k=df2.unstack()
k
# Out:
#     Stock A   Stock B
# 0  0.452820 -0.892822
# 1 -0.476880  0.393239
# 2  0.961438 -1.797336
# 3 -1.168289  0.187016

# %% [markdown]
# This operation could be applied to generate a return matrix if the input dataset is
# sorted by stock ID and date, that is, a dataset viewed as stacked one stock after another.

# %% [markdown]
# ### Python modules related to finance
#
# The following table presents about a dozen Python modules or submodules related
# to finance:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# To find out more information about economics, finance or accounting, go to the
# following web pages:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Introduction to the pandas_reader module
#
# Via this module, users can download various economics and financial via
# * Yahoo! Finance,
# * Google Finance,
# * Federal Reserve Economics Data (FRED),
# * Fama-French factors.

# %% [markdown]
# # Get IBM's trading data

# %%
! pip install pandas-datareader

# %%
import pandas_datareader.data as web

# %%
df=web.get_data_yahoo("ibm")
df.head()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2016-04-08  149.990005  148.119995  149.059998  149.350006  3293800.0
# 2016-04-11  151.949997  149.220001  150.259995  149.250000  3846100.0
# 2016-04-12  150.110001  148.580002  149.610001  149.630005  3595800.0
# 2016-04-13  151.229996  149.630005  150.750000  151.229996  3168400.0
# 2016-04-14  152.759995  150.380005  151.500000  151.160004  3176500.0
#
#              Adj Close
# Date
# 2016-04-08  119.764618
# 2016-04-11  119.684402
# 2016-04-12  119.989120
# 2016-04-13  121.272163
# 2016-04-14  121.216064

# %% [markdown]
# ### Two financial calculators
#
# Usually, when taking corporate finance or financial management,
# people rely on either Excel or a financial calculator to conduct their estimations.
# Since Python is the computational tool, a financial calculator written in Python
# would definitely enhance our understanding of both finance and Python.
#
# Here is the first financial calculator, written in Python, from `Numpy.lib.financial`

# %%
import numpy.lib.financial as fin

print(dir(fin))
# Out:
# ['Decimal', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_convert_when', '_depmsg', '_fv_dispatcher', '_g_div_gp', '_ipmt_dispatcher', '_irr_dispatcher', '_mirr_dispatcher', '_nper_dispatcher', '_npv_dispatcher', '_pmt_dispatcher', '_ppmt_dispatcher', '_pv_dispatcher', '_rate_dispatcher', '_rbl', '_when_to_num', 'array_function_dispatch', 'functools', 'fv', 'ipmt', 'irr', 'mirr', 'np', 'nper', 'npv', 'overrides', 'pmt', 'ppmt', 'pv', 'rate', 'warnings']

# %% [markdown]
# Time Value of Money, include;
#
# * fv(),
# * irr(),
# * nper(),
# * npv(),
# * pmt(),
# * pv(), and
# * rate().

# %%
# Calculating present value
fin.pv(0.1,1,0,100)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: numpy.pv is deprecated and will be removed from NumPy 1.20. Use numpy_financial.pv instead (https://pypi.org/project/numpy-financial/).
# -90.9090909090909

# %% [markdown]
# The second financial calculator is supplied by the author. There are many advantages
# of using this second financial calculator.
#
# 1. First, all its functions possess the same format of the formulas from textbooks. In other words, there is no Excel sign convention. For example, the `pv_f()` function will depend on the following formula:
#
# ![image.png](attachment:image.png)
#
# 2. Second, the formula of estimating the **present value of one future cash flow** is separated from the formula to estimate the **present value of an annuity**. This would help, especially beginners, avoid unnecessary confusions.For a comparison, the `numpy.lib.financial.pv()` function actually combines both equations (6) and (7) above.
#
# 3. Third, for each function, many examples are offered. It means users
# spend less time trying to figure out the meaning of individual functions.
# 4. Fourth, this
# second financial calculator offers more functions than the `numpy.lib.financial`
# submodule can offer.
# 5. Last but not least, users eventually learn to how to write their
# own financial calculator in Python.

# %% [markdown]
# To use such a financial calculator, users should download a file called **fincal.
# cpython-35.syc** at the author's website (http://canisius.edu/~yany/fincal.cpython-35.pyc).
#
# Assume that the executable file is saved under **c:/temp/**. To add
# **c:/temp/** to the Python path, click the rightmost Python logo on the menu bar; see
# the following screenshot:
#
# ![image.png](attachment:image.png)
#
# After clicking Add path, type **c:/temp/**; see the screen shown on the right in the
# preceding screenshot. Now, we could use `import fincal` to use all functions
# contained inside the module.

# %%
! pip install Financial
# Out:
# ...
#   Created wheel for Financial: filename=Financial-1.0-py3-none-any.whl size=2627 sha256=9f0e5185bf3d35b4d0e9c681ea251321f2417cbcd4e7548be751c6578d6f00e5
#   Stored in directory: c:\users\waqas.ali\appdata\local\pip\cache\wheels\8f\68\d6\ca3f022b8fa6272aeeb9a39dad68e7d68cd0119ac3b084cb06
# Successfully built Financial
# ...

# %%
import Financial

# %%
print(dir(Financial))
# Out:
# ['__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__']

# %% [markdown]
# To find the usage of each function, use the `help()` function;

# %%
help(Financial.__package__)
# Out:
# Help on package Financial:
#
# NAME
#     Financial
#
# PACKAGE CONTENTS
#     finance
#
# FILE
#     (built-in)
